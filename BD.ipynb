-- %% [markdown]
-- # [dbo].[Cliente]

-- %%
USE [ObaBox]
GO

-- %%
/****** Object:  Table [dbo].[Cliente]    Script Date: 11/03/2022 10:10:40 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cliente](
	[IdCliente] [int] IDENTITY(1,1) NOT NULL,
	[Nome] [varchar](60) NOT NULL,
	[Sexo] [char](1) NOT NULL,
	[DataNascimento] [date] NOT NULL,
	[EstadoCivil] [char](1) NOT NULL,
	[CPF] [char](14) NOT NULL,
	[RG] [char](20) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[IdCliente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Endereco]

-- %%
/****** Object:  Table [dbo].[Endereco]    Script Date: 11/03/2022 10:10:40 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Endereco](
	[IdEndereco] [int] IDENTITY(1,1) NOT NULL,
	[FkCliente] [int] NOT NULL,
	[IdentificadorTipo] [int] NOT NULL,
	[Logradouro] [varchar](150) NULL,
	[Numero] [varchar](10) NULL,
	[Complemento] [varchar](18) NULL,
	[Cidade] [varchar](150) NULL,
	[UF] [char](2) NULL,
	[CEP] [char](9) NULL,
PRIMARY KEY CLUSTERED 
(
	[IdEndereco] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__Endereco__CEP__3A81B327]

-- %%
ALTER TABLE [dbo].[Endereco]  WITH CHECK ADD FOREIGN KEY([FkCliente])
REFERENCES [dbo].[Cliente] ([IdCliente])
GO

-- %% [markdown]
-- # [dbo].[DeleteCliente]

-- %%
/****** Object:  StoredProcedure [dbo].[DeleteCliente]    Script Date: 11/03/2022 10:10:40 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[DeleteCliente] 
@pIdCliente int
AS  
BEGIN  
	Delete from Endereco where FkCliente = @pIdCliente
   Delete from Cliente where IdCliente = @pIdCliente
END
GO

-- %% [markdown]
-- # [dbo].[DeleteEndereco]

-- %%
/****** Object:  StoredProcedure [dbo].[DeleteEndereco]    Script Date: 11/03/2022 10:10:40 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[DeleteEndereco]
@pIdEndereco int
AS  
BEGIN  
   Delete from Endereco where IdEndereco = @pIdEndereco
END
GO

-- %% [markdown]
-- # [dbo].[GetCliente]

-- %%
/****** Object:  StoredProcedure [dbo].[GetCliente]    Script Date: 11/03/2022 10:10:40 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[GetCliente]  
AS  
BEGIN  
    -- SET NOCOUNT ON added to prevent extra result sets from  
    -- interfering with SELECT statements.  
    SET NOCOUNT ON;  
  
    -- Select statements for procedure here  
    Select * from Cliente
END
GO

-- %% [markdown]
-- # [dbo].[GetClienteId]

-- %%
/****** Object:  StoredProcedure [dbo].[GetClienteId]    Script Date: 11/03/2022 10:10:40 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[GetClienteId]  
@pIdCliente int
AS  
BEGIN  
    -- SET NOCOUNT ON added to prevent extra result sets from  
    -- interfering with SELECT statements.  
    SET NOCOUNT ON;  
  
    -- Select statements for procedure here  
    Select * from Cliente as c where c.IdCliente = @pIdCliente; 
END
GO

-- %% [markdown]
-- # [dbo].[GetEndereco]

-- %%
/****** Object:  StoredProcedure [dbo].[GetEndereco]    Script Date: 11/03/2022 10:10:40 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[GetEndereco]  
@pFkCliente int
AS  
BEGIN  
    -- SET NOCOUNT ON added to prevent extra result sets from  
    -- interfering with SELECT statements.  
    SET NOCOUNT ON;  
  
    -- Select statements for procedure here  
    Select * from Endereco where FkCliente = @pFkCliente
END
GO

-- %% [markdown]
-- # [dbo].[GetEnderecoId]

-- %%
/****** Object:  StoredProcedure [dbo].[GetEnderecoId]    Script Date: 11/03/2022 10:10:40 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[GetEnderecoId]  
@pIdEndereco int
AS  
BEGIN  
    -- SET NOCOUNT ON added to prevent extra result sets from  
    -- interfering with SELECT statements.  
    SET NOCOUNT ON;  
  
    -- Select statements for procedure here  
    Select * from Endereco as c where c.IdEndereco = @pIdEndereco; 
END
GO

-- %% [markdown]
-- # [dbo].[SetCliente]

-- %%
/****** Object:  StoredProcedure [dbo].[SetCliente]    Script Date: 11/03/2022 10:10:40 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SetCliente] 
@pNome varchar(60),
@pSexo char(1),
@pDataNascimento Date,
@pEstadoCivil char(1),
@pCPF char(14),
@pRG char(20),
@Retorno int output
AS  
BEGIN  
   if exists( select * from Cliente where CPF = @pCPF)
   begin
	   select @Retorno = 1;
	   RETURN (@Retorno)
   end
   if exists( select * from Cliente where RG = @pRG)
   begin
	   select @Retorno = 2;
	   RETURN (@Retorno)
   end
   insert into Cliente
 (Nome, Sexo, DataNascimento, EstadoCivil, CPF, RG)
 values
 ( @pNome, @pSexo, @pDataNascimento, @pEstadoCivil, @pCPF, @pRG)
 select @Retorno = 3;
RETURN (@Retorno)
END
GO

-- %% [markdown]
-- # [dbo].[SetEndereco]

-- %%
/****** Object:  StoredProcedure [dbo].[SetEndereco]    Script Date: 11/03/2022 10:10:40 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SetEndereco] 
@pFkCliente int,
@pIdentificadorTipo int,
@pLogradouro varchar(150),
@pNumero int,
@pComplemento varchar(150),
@pCidade varchar(100),
@pUF char(2),
@pCEP char(16),
@Retorno int output
AS  
BEGIN  
   insert into Endereco
 (FkCliente, IdentificadorTipo, Logradouro, Numero, Complemento, CIDADE, UF, CEP)
 values
 ( @pFkCliente, @pIdentificadorTipo, @pLogradouro, @pNumero, @pComplemento, @pCidade, @pUF, @pCEP)
END
GO

-- %% [markdown]
-- # [dbo].[UpdateCliente]

-- %%
/****** Object:  StoredProcedure [dbo].[UpdateCliente]    Script Date: 11/03/2022 10:10:40 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[UpdateCliente] 
@pIdCliente int,
@pNome varchar(60),
@pSexo char(1),
@pDataNascimento Date,
@pEstadoCivil char(1),
@pCPF char(14),
@pRG char(20),
@Retorno int output
AS  
BEGIN  
   update Cliente set
 Nome = @pNome,
 Sexo = @pSexo,
 DataNascimento = @pDataNascimento,
 EstadoCivil = @pEstadoCivil,
 CPF = @pCPF,
 RG = @pRG
 Where IdCliente = @pIdCliente

END
GO

-- %% [markdown]
-- # [dbo].[UpdateEndereco]

-- %%
/****** Object:  StoredProcedure [dbo].[UpdateEndereco]    Script Date: 11/03/2022 10:10:40 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[UpdateEndereco] 
@pIdEndereco int,
@pIdentificadorTipo int,
@pLogradouro varchar(150),
@pNumero varchar(10),
@pComplemento varchar(18),
@pCidade varchar(150),
@pUF char(2),
@pCEP char(9),
@Retorno int output
AS  
BEGIN  

   update Endereco set
 IdentificadorTipo = @pIdentificadorTipo,
 Logradouro = @pLogradouro,
 Numero = @pNumero,
 Complemento = @pComplemento,
 Cidade = @pCidade,
 UF = @pUF,
 CEP = @pCEP
 Where IdEndereco = @pIdEndereco

END
GO
